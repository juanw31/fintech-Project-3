# %%
#import pandas_datareader.data as web
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import datetime
import yfinance as yf
import plotly.express as px
from plotly.subplots import make_subplots

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

# First the layout
app = dash.Dash()
app.title = "Stock Visualization"
app.layout = html.Div(
    [
        html.I('Stock Visualization Dashboard', style = {'textAlign': 'center','color': colors['text']}),
        html.Br(),
        dcc.Input(id="input", type="text", placeholder="symbol", style={'marginRight':'10px'}),
        dcc.Input(id="input1", type="text", placeholder="Period", debounce=True),
        dcc.Input(id="input2", type="text", placeholder="Interval", debounce=True),
        dcc.Input(id="input3", type="number", placeholder="Moving Avarage", debounce=True),
         dcc.Input(id="input4", type="number", placeholder="date", debounce=True),

      
        
        
        html.Div(id="output-graph"),
    ]
)



#fig = make_subplots(rows=2, cols=2)

# Second the interaction with the user
@app.callback(
    Output(component_id="output-graph", component_property='children'),
    [Input(component_id="input", component_property="value")],
     [Input(component_id="input1", component_property="value")],
      [Input(component_id="input2", component_property="value")],
      [Input(component_id="input3", component_property="value")],
    [Input(component_id="input4", component_property="value")],


    
 
)
def update_value(input_data, period1, interval1, MA, date):
    stocks = (yf.Ticker(input_data))
    stock=stocks.history(period= period1, interval = interval1).reset_index()
    stock2=stocks.history(period= '5d', interval = '5m')#.reset_index()
    stock3=stocks.history(period= '5d', interval = '5m').reset_index()
    stock5=stocks.history(period= '5d', interval = '1d')#.reset_index()
    
    
    
    
    dff =bar(input_data).reset_index()
    dff


    
    stock5.index = stock5.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b1 =stock5.reset_index().values # convert the dataframe to values
    time_day = (b1[:,0]).tolist() # only take the first column and convert it to list

    stock2.index = stock2.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b =stock2.reset_index().values # convert the dataframe to values
    time = (b[:,0]).tolist() # only take the first column and convert it to list

    stock3['date'] = time
    stock4=stock3.set_index('date')



    short_rolling = stock['Close'].rolling(window=MA).mean()
    short_rolling2 = stock4['Close'].rolling(window=MA).mean()
    stock['mv']= short_rolling
    stock4['mv'] = short_rolling2
    
    
    
    
    
    
    
    
    
    
    
    
  
 
    fig = make_subplots(rows=2, cols=2, subplot_titles=(input_data + ' ' + time_day[4], input_data + ' ' + time_day[date], "Plot 3", "Plot 4"))

    
    
    fig = fig.add_trace(go.Scatter(x=stock['Datetime'], y=stock["Open"]),row=1, col=1)
    
    fig = fig.add_trace(go.Candlestick(x=stock['Datetime'],open=stock['Open'],high=stock['High'],low=stock['Low'],close=stock['Close']),row=1, col=1)
    
    #fig = fig.add_trace(go.Scatter(x=stock.loc[date]['Datetime'].to_list(), y=stock.loc[date]["Open"].to_list()) ,row=1, col=2) #secondary_y=radio_value == 'Secondary',row=1, col=2)
    
    fig = fig.add_trace(go.Candlestick(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]],open=stock4['Open'].loc[time_day[date-1] :time_day[date]],high=stock4['High'].loc[time_day[date-1] :time_day[date]],low=stock4['Low'].loc[time_day[date-1] :time_day[date]],close=stock4['Close'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)

    fig = fig.add_trace(go.Scatter(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]], y=stock4['mv'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)
    fig.add_trace(go.Bar(x=dff['date'], y=dff[input_data],marker=dict(color=[4, 5, 6], coloraxis="coloraxis")),3, 3)
    
    fig2=px.bar(dff ,barmode='group',title= 'Compound sentiment scores of news aticles')
    
    
    stocks = (yf.Ticker('msft'))
    stock=stocks.history(period= '1d', interval = '1m').reset_index()
    #fundementals = [msft.dividends[-1], 

    df =stocks.info


    df = pd.DataFrame([df.keys(), list(df.values())]).T
    df = df.rename(columns={0: "a", 1: "c"})

    #fig = (go.Figure(data=[go.Table(header=dict(values=list(df.columns),fill_color='paleturquoise',align='left'),cells=dict(values=[df.a, df.c],fill_color='lavender',align='left'))],row=1, col=2))




    
    

    
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text =input_data + time_day[date])
    #fig.update_xaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
   



    
    
    return dcc.Graph(id="demo" , figure=fig) 

    
   
    
    
    
if __name__ == "__main__":
    app.run_server(debug=False, port = 8223)

# %%
def bar (input_data):    # Imports

from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# Ticker news
news_tables = {}
tickers = [input_data]

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]

        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]

        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])

# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# # Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# # Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# # Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head(50)

import plotly.express as px
import plotly.graph_objects as go
import yfinance as yf

data=yf.Ticker(ticker).history(period= "5d", interval = "1d").reset_index()
fig = px.line(data, x='Date', y="Open",title="Close Prices")

mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()
mean_scores1 = mean_scores.unstack()
mean_scores11 = mean_scores1.xs('compound', axis="columns").transpose()

#fig2=px.bar(mean_scores11,barmode='group',title= 'Compound sentiment scores of news aticles')
# fig.add_trace(fig2)



#mean_scores11.reset_index()
#fig2=px.bar(mean_scores11,y='amzn',barmode='group',title= 'Compound sentiment scores of news aticles')

# %%
dff =bar('ba').reset_index()
dff#['date']#.to_list()

# %%
#import pandas_datareader.data as web
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import datetime
import yfinance as yf
import plotly.express as px
from plotly.subplots import make_subplots




import pandas as pd
import yfinance as yf
import plotly.graph_objects as go


colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

# First the layout
app = dash.Dash()
app.title = "Stock Visualization"
app.layout = html.Div(
    [
        html.I('Stock Visualization Dashboard', style = {'textAlign': 'center','color': colors['text']}),
        html.Br(),
        dcc.Input(id="input", type="text", placeholder="symbol", style={'marginRight':'10px'}),
        dcc.Input(id="input1", type="text", placeholder="Period", debounce=True),
        dcc.Input(id="input2", type="text", placeholder="Interval", debounce=True),
        dcc.Input(id="input3", type="number", placeholder="Moving Avarage", debounce=True),
        dcc.Dropdown(id='demo-dropdown',options=[{'label': 'Yesterday', 'value': 3},{'label': 'the day before yesterday', 'value': 2},{'label': 'two days ago', 'value': 1}],value='select past 3 days stock performance'),
         

      #app.layout = html.Div(html.H1('Heading', style={'backgroundColor':'blue'})
        
        
        html.Div(id="output-graph"),
    ]
)



#fig = make_subplots(rows=2, cols=2)

# Second the interaction with the user
@app.callback(
    Output(component_id="output-graph", component_property='children'),
    [Input(component_id="input", component_property="value")],
     [Input(component_id="input1", component_property="value")],
      [Input(component_id="input2", component_property="value")],
      [Input(component_id="input3", component_property="value")],
    [Input(component_id="demo-dropdown", component_property="value")],


    
 
)
def update_value(input_data, period1, interval1, MA, date):
    #stocks = (yf.Ticker(input_data))
    stock=stocks.history(period= period1, interval = interval1).reset_index()
    stock2=stocks.history(period= '5d', interval = '5m')#.reset_index()
    stock3=stocks.history(period= '5d', interval = '5m').reset_index()
    stock5=stocks.history(period= '5d', interval = '1d')#.reset_index()
    
    stock5.index = stock5.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b1 =stock5.reset_index().values # convert the dataframe to values
    time_day = (b1[:,0]).tolist() # only take the first column and convert it to list

    stock2.index = stock2.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b =stock2.reset_index().values # convert the dataframe to values
    time = (b[:,0]).tolist() # only take the first column and convert it to list

    stock3['date'] = time
    stock4=stock3.set_index('date')



    short_rolling = stock['Close'].rolling(window=MA).mean()
    short_rolling2 = stock4['Close'].rolling(window=MA).mean()
    stock['mv']= short_rolling
    stock4['mv'] = short_rolling2
  
    fig = make_subplots(rows=3, cols=2, subplot_titles=(input_data + ' ' + time_day[4], input_data + ' ' + time_day[date], "", "", " Close Prices for the last week", "Plot 6"))

    
    
    fig = fig.add_trace(go.Scatter(x=stock['Datetime'], y=stock["Open"]),row=1, col=1)
    
    fig = fig.add_trace(go.Candlestick(x=stock['Datetime'],open=stock['Open'],high=stock['High'],low=stock['Low'],close=stock['Close']),row=1, col=1)
    #fig.update_layout(xaxis_rangeslider_visible=False)
    
    
    #fig = fig.add_trace(go.Scatter(x=stock.loc[date]['Datetime'].to_list(), y=stock.loc[date]["Open"].to_list()) ,row=1, col=2) #secondary_y=radio_value == 'Secondary',row=1, col=2)
    
    fig = fig.add_trace(go.Candlestick(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]],open=stock4['Open'].loc[time_day[date-1] :time_day[date]],high=stock4['High'].loc[time_day[date-1] :time_day[date]],low=stock4['Low'].loc[time_day[date-1] :time_day[date]],close=stock4['Close'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)
    #fig.update_layout(xaxis_rangeslider_visible=False)
    fig = fig.add_trace(go.Scatter(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]], y=stock4['mv'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)
    
    fig = fig.add_trace(go.Scatter(x=stock3['Datetime'], y=stock3['Close']),row=3, col=1)
    #fig = fig.add_trace(go.Bar(x=dff['date'], y=dff[input_data],marker=dict(color=[4, 5, 6], coloraxis="coloraxis")),row = 3, col = 3)
    
 


    
    #fig = fig.add_trace(go.Scatter(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]], y=stock4['mv'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)
    
    
    stocks = (yf.Ticker('msft'))
    stock=stocks.history(period= '1d', interval = '1m').reset_index()
    #fundementals = [msft.dividends[-1], 

    df =stocks.info


    df = pd.DataFrame([df.keys(), list(df.values())]).T
    df = df.rename(columns={0: "a", 1: "c"})

    #fig = (go.Figure(data=[go.Table(header=dict(values=list(df.columns),fill_color='paleturquoise',align='left'),cells=dict(values=[df.a, df.c],fill_color='lavender',align='left'))],row=1, col=2))


    
    

    
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    #fig.update_layout(width=2200,height=600,title_text =input_data + time_day[date])
    #fig.update_xaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
   



    
    
    return dcc.Graph(id="demo" , figure=fig) 

    
   
    
    
    
if __name__ == "__main__":
    app.run_server(debug=False, port = 8261)
# Out:
# Dash is running on http://127.0.0.1:8261/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8261/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash/deps/react@16.v1_21_0m1626815353.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash/deps/polyfill@7.v1_21_0m1626815353.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash/deps/prop-types@15.v1_21_0m1626815353.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash/deps/react-dom@16.v1_21_0m1626815353.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_4m1626815352.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_17_1m1626815353.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v1_21_0m1626815353.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_17_1m1626815353.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_favicon.ico?v=1.21.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:23] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:24] "GET /_favicon.ico?v=1.21.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Jul/2021 12:27:24] "GET /_dash-component-suites/dash_core_components/async-dropdown.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:24] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:25] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:29] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:31] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:34] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\goshl\anaconda3\envs\Trading\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-1-ff24f18eb3df>", line 64, in update_value
#     stock=stocks.history(period= period1, interval = interval1).reset_index()
# UnboundLocalError: local variable 'stocks' referenced before assignment
# 127.0.0.1 - - [31/Jul/2021 12:27:34] "POST /_dash-update-component HTTP/1.1" 500 -

# %%
import bar1
bar1.bar()

# %%
stock3['date'] = time
    stock4=stock3.set_index('date')
 fig.add_trace(go.Bar(x=dff['date'], y=dff[input_data],marker=dict(color=[4, 5, 6], coloraxis="coloraxis")),3, 3)

# %%
import plotly.figure_factory as ff

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import datetime
import yfinance as yf
import plotly.express as px
from plotly.subplots import make_subplots

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots


fig = make_subplots(rows=2, cols=2)

data_matrix = [['Country', 'Year', 'Population'],['United States', 2000, 282200000],['Canada', 2000, 27790000],['United States', 2005, 295500000],['Canada', 2005, 32310000],['United States', 2010, 309000000],['Canada', 2010, 34000000]]
place = (row=1, col=1)
fig = ff.create_table(data_matrix, place)
       
fig.show()

# %%
import plotly.figure_factory as ff

text = [['Team', 'Rank'], ['A', 1], ['B', 2], ['C', 3], ['D', 4], ['E', 5], ['F', 6]]

colorscale = [[0, '#272D31'],[.5, '#ffffff'],[1, '#ffffff']]
font=['#FCFCFC', '#00EE00', '#008B00', '#004F00', '#660000', '#CD0000', '#FF3030']

fig = ff.create_table(text, colorscale=colorscale, font_colors=font)
fig.layout.width=250
fig.show()

# %%
 stock4['mv'] = short_rolling
import plotly.graph_objects as go

import pandas as pd
import yfinance as yf
stocks = (yf.Ticker('ba'))
stock=stocks.history(period= '1d', interval = '1m').reset_index()

fig = fig.add_trace(go.Candlestick(x=stock['Datetime'],
                open=stock['Open'],
                high=stock['High'],
                low=stock['Low'],
                close=stock['Close']))


fig.update_layout(width=1000,height=600,title_text = 'Plot')

fig.show()

# %%
def update_output():
    fig = make_subplots(rows=1, cols=2)

    stocks = (yf.Ticker('ba'))
    stock=stocks.history(period= '1d', interval = '1m').reset_index()

    fig = go.Figure(data=[go.Candlestick(x=stock['Datetime'],
                    open=stock['Open'],
                    high=stock['High'],
                    low=stock['Low'],
                    close=stock['Close'])])
    fig.update_layout(width=1000,height=600,title_text = 'Plot')
    
    fig = fig.add_trace(go.Scatter(x=stock['Datetime'], y=stock["Open"]),row=1, col=2)

# %%
  dcc.Dropdown(id='demo-dropdown',options=[{'label': 'New York City'}],value='NYC'),
import         [Input(component_id="demo-dropdown", component_property="value")],



stock['date'] = time
stock = stock.set_index("date")

short_rolling = stock['Close'].rolling(window=5).mean()
stock['mv']= short_rolling
stock

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import datetime
import yfinance as yf
import plotly.express as px
from plotly.subplots import make_subplots

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots


stocks = (yf.Ticker('ba'))
stock=stocks.history(period= '1d', interval = '5m').reset_index()
stock2=stocks.history(period= '5d', interval = '5m')#.reset_index()
stock3=stocks.history(period= '5d', interval = '5m').reset_index()
stock5=stocks.history(period= '5d', interval = '1d')#.reset_index()


stock5.index = stock5.index.astype(str) # convert the format of the string to string (from date time format to string format)
b1 =stock5.reset_index().values # convert the dataframe to values
time_day = (b1[:,0]).tolist() # only take the first column and convert it to list

stock2.index = stock2.index.astype(str) # convert the format of the string to string (from date time format to string format)
b =stock2.reset_index().values # convert the dataframe to values
time = (b[:,0]).tolist() # only take the first column and convert it to list

stock3['date'] = time
stock4=stock3.set_index('date')
#fig = fig.add_trace(go.Scatter(x=stock.loc[date]['Datetime'].to_list(), y=stock.loc[date]["Open"].to_list()) ,row=1, col=2) #secondary_y=radio_value == 'Secondary',row=1, col=2)
stock4

short_rolling = stock4['Close'].rolling(window=21).mean()

stock4['mv'] = short_rolling
stock4

# %%
stock4.loc[time_day[3] :time_day[4]]['Open'].to_list()
fig = go.Figure(data=[go.Candlestick(x=stock4['Datetime'].loc[time_day[3] :time_day[4]],
                open=stock4['Open'].loc[time_day[3] :time_day[4]],
                high=stock4['High'].loc[time_day[3] :time_day[4]],
                low=stock4['Low'].loc[time_day[3] :time_day[4]],
                close=stock4['Close'].loc[time_day[3] :time_day[4]])])

fig.show()

# %%
#import pandas_datareader.data as web
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import datetime
import yfinance as yf
import plotly.express as px
from plotly.subplots import make_subplots

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

# First the layout
app = dash.Dash()
app.title = "Stock Visualization"
app.layout = html.Div(
    [
        html.I('Stock Visualization Dashboard', style = {'textAlign': 'center','color': colors['text']}),
        html.Br(),
        dcc.Input(id="input", type="text", placeholder="symbol", style={'marginRight':'10px'}),
        dcc.Input(id="input1", type="text", placeholder="Period", debounce=True),
        dcc.Input(id="input2", type="text", placeholder="Interval", debounce=True),
        dcc.Input(id="input3", type="number", placeholder="Moving Avarage", debounce=True),
         dcc.Input(id="input4", type="number", placeholder="date", debounce=True),

      
        
        
        html.Div(id="output-graph"),
    ]
)



#fig = make_subplots(rows=2, cols=2)

# Second the interaction with the user
@app.callback(
    Output(component_id="output-graph", component_property='children'),
    [Input(component_id="input", component_property="value")],
     [Input(component_id="input1", component_property="value")],
      [Input(component_id="input2", component_property="value")],
      [Input(component_id="input3", component_property="value")],
    [Input(component_id="input4", component_property="value")],


    
 
)
def update_value(input_data, period1, interval1, MA, date):
    stocks = (yf.Ticker(input_data))
    stock=stocks.history(period= period1, interval = interval1).reset_index()
    stock2=stocks.history(period= '5d', interval = '5m')#.reset_index()
    stock3=stocks.history(period= '5d', interval = '5m').reset_index()
    stock5=stocks.history(period= '5d', interval = '1d')#.reset_index()
    
    
    
    
    dff =bar(input_data).reset_index()
    dff


    
    stock5.index = stock5.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b1 =stock5.reset_index().values # convert the dataframe to values
    time_day = (b1[:,0]).tolist() # only take the first column and convert it to list

    stock2.index = stock2.index.astype(str) # convert the format of the string to string (from date time format to string format)
    b =stock2.reset_index().values # convert the dataframe to values
    time = (b[:,0]).tolist() # only take the first column and convert it to list

    stock3['date'] = time
    stock4=stock3.set_index('date')



    short_rolling = stock['Close'].rolling(window=MA).mean()
    short_rolling2 = stock4['Close'].rolling(window=MA).mean()
    stock['mv']= short_rolling
    stock4['mv'] = short_rolling2
    
    
    
    
    
    
    
    
    
    
    
    
  
 
    fig = make_subplots(rows=2, cols=2, subplot_titles=(input_data + ' ' + time_day[4], input_data + ' ' + time_day[date], "Plot 3", "Plot 4"))

    
    
    fig = fig.add_trace(go.Scatter(x=stock['Datetime'], y=stock["Open"]),row=1, col=1)
    
    fig = fig.add_trace(go.Candlestick(x=stock['Datetime'],open=stock['Open'],high=stock['High'],low=stock['Low'],close=stock['Close']),row=1, col=1)
    
    #fig = fig.add_trace(go.Scatter(x=stock.loc[date]['Datetime'].to_list(), y=stock.loc[date]["Open"].to_list()) ,row=1, col=2) #secondary_y=radio_value == 'Secondary',row=1, col=2)
    
    fig = fig.add_trace(go.Candlestick(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]],open=stock4['Open'].loc[time_day[date-1] :time_day[date]],high=stock4['High'].loc[time_day[date-1] :time_day[date]],low=stock4['Low'].loc[time_day[date-1] :time_day[date]],close=stock4['Close'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)

    fig = fig.add_trace(go.Scatter(x=stock4['Datetime'].loc[time_day[date-1] :time_day[date]], y=stock4['mv'].loc[time_day[date-1] :time_day[date]]),row=1, col=2)
    fig.add_trace(go.Bar(x=dff['date'], y=dff[input_data],marker=dict(color=[4, 5, 6], coloraxis="coloraxis")),3, 3)
    
    fig2=px.bar(dff ,barmode='group',title= 'Compound sentiment scores of news aticles')
    
    
    stocks = (yf.Ticker('msft'))
    stock=stocks.history(period= '1d', interval = '1m').reset_index()
    #fundementals = [msft.dividends[-1], 

    df =stocks.info


    df = pd.DataFrame([df.keys(), list(df.values())]).T
    df = df.rename(columns={0: "a", 1: "c"})

    #fig = (go.Figure(data=[go.Table(header=dict(values=list(df.columns),fill_color='paleturquoise',align='left'),cells=dict(values=[df.a, df.c],fill_color='lavender',align='left'))],row=1, col=2))




    
    

    
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text = 'Plot')
    fig.update_layout(width=2200,height=600,title_text =input_data + time_day[date])
    #fig.update_xaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
   



    
    
    return dcc.Graph(id="demo" , figure=fig) 

    
   
    
    
    
if __name__ == "__main__":
    app.run_server(debug=False, port = 8223)
